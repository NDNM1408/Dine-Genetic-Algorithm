# %%
# Tự chơi game
# !python HumanPlay.py
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.9.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Xem if else chơi
# !python IfElse.py
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.9.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Thực hiện huấn luyện
# !python train.py
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.9.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Top Fitness:[56.5 58.1 65.3 93.4 96. ]
# Top Fitness:[51.  51.  51.  69.8 97.5]
# Top Fitness:[ 51.   51.   51.   87.8 125.1]
# Top Fitness:[102.4 102.7 141.9 142.1 142.1]
# Top Fitness:[102.7 133.8 142.1 188.9 190.2]
# Top Fitness:[121.7 122.2 143.8 144.  144.2]
# Top Fitness:[589.2 608.9 609.1 609.2 609.2]
# Top Fitness:[144.  144.1 144.2 144.2 144.2]

# %%
# Thực hiện xem khủng long chơi sau khi train
# !python GAEval.py
# Out:
# pygame 2.5.0 (SDL 2.28.0, Python 3.9.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# W1: [[ 2.13552861  0.75489828 -1.85524156  1.18508351  1.6619403 ]
#  [-0.23360476  0.45882194 -0.7461203  -1.46118434  0.39207103]
#  [-1.23775628  0.40317661  0.3797037   0.08926194  1.19772725]
#  [-0.17567565 -0.66773637  1.65716243 -0.96146499  1.60875167]
#  [ 0.29124997  0.20220478 -0.40602565  0.1584023   2.08750475]
#  [-1.07871499  0.23183422  0.68719313  0.92408419  2.46877223]
#  [-0.34621872  0.85998804 -1.87679164  0.68548349 -1.71953   ]
#  [ 1.84679429  0.35404656 -0.69678312  0.02673868 -0.72234833]
#  [-0.72941806 -0.72392696  0.69751781  0.88791881 -0.10540672]
#  [-1.90276218  1.31176824  0.68382231  1.19137269 -1.63864462]
#  [ 0.66928133 -0.82868323  0.84337282 -1.28760039 -1.51333237]
#  [-1.0967558   0.8136535   0.83218486 -0.29162203 -0.54731906]
#  [-0.03866984  0.9786907   1.03463484 -0.6980429   1.91821105]
# ...
