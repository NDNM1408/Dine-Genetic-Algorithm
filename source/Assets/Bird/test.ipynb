# %%
import PIL
from PIL import Image

# %%
Image.open('Bird1.png').convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=97x68>

# %%
Image.open('Bird2.png').convert('RGB').size
# Out:
# (93, 62)

# %%
Image.open('Bird3.png').convert('RGB')
# Out:
# <PIL.Image.Image image mode=RGB size=194x136>

# %%
Image.open('Bird2.png').resize((186, 123)).save('Bird4.png')

# %%
pip install rembg
# Out:
# ...
#   WARNING: The scripts lsm2bin.exe, tiff2fsspec.exe, tiffcomment.exe and tifffile.exe are installed in 'c:\Users\ndnm\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts imageio_download_bin.exe and imageio_remove_bin.exe are installed in 'c:\Users\ndnm\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script humanfriendly.exe is installed in 'c:\Users\ndnm\AppData\Local\Programs\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
#
#
# ...

# %%
from rembg import remove
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from rembg import remove
#
# ModuleNotFoundError: No module named 'rembg'
